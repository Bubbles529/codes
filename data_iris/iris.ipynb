# %%
# %run iris.py

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data, target, target_names, feature_names,data_pd = get_data_sklearn()

# %%
show_class_dis(data_pd)
# Out:
# |类别|样本数|
# |-|-|
# |versicolor|50|
# |setosa|50|
# |virginica|50|

# %%
pca, data_pca = PCA_Process(data, target, target_names)

# %%
pca_ = show_pca_en(data)

# %%
iso_map(data, target, target_names)
# Out:
# (Isomap(eigen_solver='auto', max_iter=None, n_components=2, n_neighbors=5,
#      neighbors_algorithm='auto', path_method='auto', tol=0),
#  array([[-0.1179681 , -0.37788956],
#         [-0.11431511, -0.33297801],
#         [-0.11454629, -0.33653793],
#         [-0.114109  , -0.33099684],
#         [-0.11738484, -0.36900653],
#         [-0.10904166, -0.24441428],
#         [-0.11490662, -0.34193216],
#         [-0.11861553, -0.38810833],
#         [-0.1081599 , -0.25030473],
#         [-0.11277195, -0.31509606],
#         [-0.11461233, -0.3252318 ],
#         [-0.11804991, -0.38220443],
#         [-0.11251757, -0.30976609],
#         [-0.10434695, -0.1991283 ],
#         [-0.10124068, -0.13152634],
#         [-0.09160711,  0.00875045],
#         [-0.10913429, -0.24527772],
#         [-0.11787326, -0.37629947],
#         [-0.10678123, -0.21221391],
#         [-0.11489925, -0.33064624],
#         [-0.11433779, -0.3250572 ],
#         [-0.11536892, -0.33912628],
#         [-0.11220729, -0.30332559],
#         [-0.11443294, -0.33514853],
#         [-0.11473961, -0.34025956],
#         [-0.1115081 , -0.29894004],
#         [-0.11721143, -0.37063531],
#         [-0.11782563, -0.37349431],
#         [-0.118083  , -0.37851163],
#         [-0.11631434, -0.36011213],
#         [-0.11526746, -0.34642066],
#         [-0.1141014 , -0.32561439],
#         [-0.1079924 , -0.23066886],
#         [-0.09942531, -0.10460895],
#         [-0.11277195, -0.31509606],
#         [-0.1174463 , -0.37294242],
#         [-0.11397485, -0.31940117],
#         [-0.11277195, -0.31509606],
#         [-0.10847   , -0.2552981 ],
#         [-0.11841649, -0.38396687],
#         [-0.11769603, -0.37468531],
#         [-0.09277477, -0.04059219],
#         [-0.11026281, -0.28045796],
#         [-0.11527676, -0.34221162],
#         [-0.10890586, -0.24737148],
#         [-0.11289839, -0.31524851],
#         [-0.11435156, -0.32297938],
#         [-0.11352657, -0.32433792],
#         [-0.11551961, -0.33837416],
#         [-0.11801946, -0.38007593],
#         [ 0.15633807,  0.36917025],
#         [ 0.46262205,  0.53317918],
#         [-0.013886  ,  0.37423872],
#         [ 2.03738101, -0.48440179],
#         [ 0.46302237,  0.25550673],
#         [ 1.41348168,  0.20903425],
#         [ 0.49685653,  0.68529531],
#         [ 2.60294293, -1.32157893],
#         [ 0.43303429,  0.21354081],
#         [ 2.2259358 , -0.47878381],
#         [ 2.53783657, -1.22639045],
#         [ 1.30466634,  0.23832417],
#         [ 1.33408982, -0.17280461],
#         [ 0.85759043,  0.62851931],
#         [ 1.9835755 , -0.52102891],
#         [ 0.4242207 ,  0.29980441],
#         [ 1.40604574,  0.24505557],
#         [ 1.81976826, -0.25311117],
#         [ 0.63334719,  0.4564632 ],
#         [ 1.8348515 , -0.37601678],
#         [ 0.4475048 ,  0.94463448],
#         [ 1.29308627,  0.01271688],
#         [ 0.14284219,  0.56150762],
#         [ 1.04385775,  0.55172541],
#         [ 0.76370969,  0.18659942],
#         [ 0.49292926,  0.27851186],
#         [ 0.12821966,  0.27627434],
#         [-0.24024086,  0.34211734],
#         [ 1.03818729,  0.46735244],
#         [ 2.02728184, -0.6505918 ],
#         [ 1.92893573, -0.47884407],
#         [ 2.04453507, -0.59230075],
#         [ 1.62695529, -0.26356915],
#         [ 0.03487682,  0.85726073],
#         [ 1.58858774,  0.10967099],
#         [ 0.78778025,  0.70663122],
#         [ 0.15598851,  0.41244038],
#         [ 0.75301982,  0.33198449],
#         [ 1.65520497, -0.02279184],
#         [ 1.9615722 , -0.344916  ],
#         [ 1.71451769, -0.03432934],
#         [ 0.85905416,  0.52680636],
#         [ 1.6461623 , -0.23303283],
#         [ 2.54729852, -1.24392143],
#         [ 1.75749712, -0.06518159],
#         [ 1.63899713, -0.00633798],
#         [ 1.60417983,  0.00903164],
#         [ 0.97330527,  0.2715744 ],
#         [ 2.68835457, -1.45232003],
#         [ 1.66944311, -0.06881449],
#         [-1.69490646,  0.30583548],
#         [ 0.19923343,  1.10501416],
#         [-1.93082141, -0.03182124],
#         [-0.8955018 ,  0.70326468],
#         [-1.33031856,  0.3710169 ],
#         [-3.02410553, -1.03243667],
#         [ 2.24185573, -0.48201785],
#         [-2.47402923, -0.4766449 ],
#         [-1.0038336 ,  0.64968535],
#         [-2.34387713, -0.2210576 ],
#         [-0.65358697,  0.44109934],
#         [-0.6170255 ,  0.65779296],
#         [-1.41841909,  0.29743534],
#         [ 0.20634723,  1.161002  ],
#         [ 0.37157554,  1.30647926],
#         [-0.96511977,  0.45557598],
#         [-0.83501435,  0.70456079],
#         [-3.26817858, -1.10577374],
#         [-3.37539453, -1.41930426],
#         [ 0.14775254,  0.65204937],
#         [-1.77250931,  0.11270055],
#         [ 0.33733324,  1.22867692],
#         [-3.08845654, -1.09922669],
#         [-0.01339932,  0.74563203],
#         [-1.65929194,  0.27435003],
#         [-2.29344667, -0.25882415],
#         [ 0.09189089,  0.83513278],
#         [ 0.29414125,  0.86001957],
#         [-1.00114732,  0.51862549],
#         [-2.09253997, -0.16299472],
#         [-2.38355164, -0.39515038],
#         [-3.33282466, -1.17492632],
#         [-1.06872498,  0.4857876 ],
#         [ 0.16477399,  0.85310373],
#         [-0.48326674,  0.86818279],
#         [-2.59971985, -0.60203307],
#         [-1.34297272,  0.26507832],
#         [-0.84880636,  0.71300701],
#         [ 0.39397956,  0.78328662],
#         [-1.3898585 ,  0.19808465],
#         [-1.64548035,  0.28521747],
#         [-1.13176546,  0.33573366],
#         [ 0.19923343,  1.10501416],
#         [-1.7514374 ,  0.16361612],
#         [-1.82137926,  0.17011598],
#         [-1.0310462 ,  0.36074855],
#         [-0.22381318,  0.66549245],
#         [-0.66469923,  0.54316959],
#         [-1.11595675,  0.35911792],
#         [ 0.37552581,  1.0084687 ]]))

# %%
knn_grid = find_best_knn(data,target,cv=10)

# %%
knn_grid.grid_scores_
# Out:
# [mean: 0.96000, std: 0.05333, params: {'n_neighbors': 1, 'weights': 'uniform'},
#  mean: 0.96000, std: 0.05333, params: {'n_neighbors': 1, 'weights': 'distance'},
#  mean: 0.95333, std: 0.05207, params: {'n_neighbors': 2, 'weights': 'uniform'},
#  mean: 0.96000, std: 0.05333, params: {'n_neighbors': 2, 'weights': 'distance'},
#  mean: 0.96667, std: 0.04472, params: {'n_neighbors': 3, 'weights': 'uniform'},
#  mean: 0.96667, std: 0.04472, params: {'n_neighbors': 3, 'weights': 'distance'},
#  mean: 0.96667, std: 0.04472, params: {'n_neighbors': 5, 'weights': 'uniform'},
#  mean: 0.96667, std: 0.04472, params: {'n_neighbors': 5, 'weights': 'distance'},
#  mean: 0.96667, std: 0.04472, params: {'n_neighbors': 8, 'weights': 'uniform'},
#  mean: 0.96667, std: 0.04472, params: {'n_neighbors': 8, 'weights': 'distance'},
#  mean: 0.96667, std: 0.04472, params: {'n_neighbors': 10, 'weights': 'uniform'},
#  mean: 0.97333, std: 0.03266, params: {'n_neighbors': 10, 'weights': 'distance'},
#  mean: 0.97333, std: 0.03266, params: {'n_neighbors': 15, 'weights': 'uniform'},
#  mean: 0.98000, std: 0.03055, params: {'n_neighbors': 15, 'weights': 'distance'},
#  mean: 0.98000, std: 0.03055, params: {'n_neighbors': 20, 'weights': 'uniform'},
#  mean: 0.96667, std: 0.04472, params: {'n_neighbors': 20, 'weights': 'distance'},
#  mean: 0.96667, std: 0.03333, params: {'n_neighbors': 25, 'weights': 'uniform'},
#  mean: 0.97333, std: 0.03266, params: {'n_neighbors': 25, 'weights': 'distance'},
#  mean: 0.95333, std: 0.04269, params: {'n_neighbors': 30, 'weights': 'uniform'},
#  mean: 0.96667, std: 0.03333, params: {'n_neighbors': 30, 'weights': 'distance'},
#  mean: 0.94667, std: 0.04989, params: {'n_neighbors': 35, 'weights': 'uniform'},
#  mean: 0.96667, std: 0.03333, params: {'n_neighbors': 35, 'weights': 'distance'},
#  mean: 0.95333, std: 0.04269, params: {'n_neighbors': 40, 'weights': 'uniform'},
#  mean: 0.96667, std: 0.04472, params: {'n_neighbors': 40, 'weights': 'distance'}]

# %%
grid_knn = knn_grid

# %%
knn_grid.best_score_, knn_grid.best_estimator_, knn_grid.best_params_
# Out:
# (0.97999999999999998,
#  KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#             metric_params=None, n_jobs=1, n_neighbors=15, p=2,
#             weights='distance'),
#  {'n_neighbors': 15, 'weights': 'distance'})

# %%
grid_dc_tree = find_best_decisiontree(data, target, cv=10)

# %%
grid_dc_tree.grid_scores_
# Out:
# [mean: 0.96000, std: 0.04422, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 10},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 2},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 3},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 5},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 8},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 2},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 3},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 5},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 8},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 10, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 10},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 2},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 3},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 5},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 8},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 2},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 3},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 5},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 8},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 15, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 10},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 2},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 3},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 5},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 8},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 2},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 3},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 5},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 8},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 20, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 2},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 10},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 2},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 3},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 5},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 8},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 2},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 3},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 5},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 8},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 30, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 1, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 2, 'min_samples_split': 10},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 2},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 3},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 5},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 8},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 3, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 2},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 5, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 3},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 5},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 8},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': None, 'criterion': 'gini', 'min_samples_leaf': 8, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 2},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 10},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 2},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 3},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 5},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 8},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 2},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 3},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 5},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 8},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 10, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 10},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 2},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 3},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 5},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 8},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 2},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 3},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 5},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 8},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 15, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.04422, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 2},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 10},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 2},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 3},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 5},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 8},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 2},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 3},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 5},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 8},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 20, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.04422, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 2},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 10},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 2},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 3},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 5},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 8},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 2},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 3},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 5},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 8},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': 30, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.04269, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.03266, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 2, 'min_samples_split': 10},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 2},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 3},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 5},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 8},
#  mean: 0.96667, std: 0.03333, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 3, 'min_samples_split': 10},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 2},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 3},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 5},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 8},
#  mean: 0.96000, std: 0.05333, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 5, 'min_samples_split': 10},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 2},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 3},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 5},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 8},
#  mean: 0.95333, std: 0.05207, params: {'max_depth': None, 'criterion': 'entropy', 'min_samples_leaf': 8, 'min_samples_split': 10}]

# %%
grid_dc_tree.best_score_, grid_dc_tree.best_estimator_, grid_dc_tree.best_params_
# Out:
# (0.96666666666666667,
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#              max_features=None, max_leaf_nodes=None, min_samples_leaf=3,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              presort=False, random_state=None, splitter='best'),
#  {'criterion': 'gini',
#   'max_depth': 10,
#   'min_samples_leaf': 3,
#   'min_samples_split': 2})

# %%
grid_logistic = find_best_logistic(data, target, cv=10)

# %%
grid_logistic.grid_scores_
# Out:
# [mean: 0.83333, std: 0.05375, params: {'C': 0.1},
#  mean: 0.94667, std: 0.04989, params: {'C': 0.5},
#  mean: 0.95333, std: 0.06000, params: {'C': 1},
#  mean: 0.96667, std: 0.06146, params: {'C': 5},
#  mean: 0.96667, std: 0.06146, params: {'C': 10}]

# %%
grid_logistic.best_score_, grid_logistic.best_estimator_, grid_logistic.best_params_
# Out:
# (0.96666666666666667,
#  LogisticRegression(C=5, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#            penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#            verbose=0, warm_start=False),
#  {'C': 5})

# %%
grid_svm = find_best_svm(data, target, cv=10)

# %%
grid_svm.grid_scores_[0][1]
# Out:
# 0.97333333333333338

# %%
grid_svm.best_score_, grid_svm.best_estimator_, grid_svm.best_params_
# Out:
# (0.98666666666666669, SVC(C=0.5, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#    max_iter=-1, probability=False, random_state=None, shrinking=True,
#    tol=0.001, verbose=False), {'C': 0.5, 'kernel': 'linear'})

# %%
grid_random_forest = find_best_random_forest(data, target, cv=10)

# %%
type(grid_random_forest.grid_scores_)
# Out:
# list

# %%
type(grid_random_forest.grid_scores_[0])
# Out:
# sklearn.grid_search._CVScoreTuple

# %%
grid_random_forest.grid_scores_
# Out:
# [mean: 0.96000, std: 0.03266, params: {'n_estimators': 10},
#  mean: 0.96000, std: 0.03266, params: {'n_estimators': 20},
#  mean: 0.95333, std: 0.04269, params: {'n_estimators': 35},
#  mean: 0.96000, std: 0.04422, params: {'n_estimators': 50},
#  mean: 0.95333, std: 0.04269, params: {'n_estimators': 80},
#  mean: 0.96000, std: 0.04422, params: {'n_estimators': 100},
#  mean: 0.96667, std: 0.03333, params: {'n_estimators': 120},
#  mean: 0.96000, std: 0.04422, params: {'n_estimators': 150},
#  mean: 0.96000, std: 0.04422, params: {'n_estimators': 200}]

# %%
grid_random_forest.best_score_, grid_random_forest.best_estimator_, grid_random_forest.best_params_
# Out:
# (0.96666666666666667,
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=120, n_jobs=1,
#              oob_score=False, random_state=0, verbose=0, warm_start=False),
#  {'n_estimators': 120})

# %%
# %run -i iris.py

# %%
show_confusion_matrix('SVC', data, target, target_names,5, 0.3)
# Out:
# score:  0.977777777778
# [[21  0  0]
#  [ 0  9  1]
#  [ 0  0 14]]
# |实际\预测|setosa|versicolor|virginica|
# |-|-|-|-|
# |setosa|21|0|0|
# |versicolor|0|9|1|
# |virginica|0|0|14|
# class: 0 setosa rate: 1.0
# class: 1 versicolor rate: 0.9
# predict to: virginica  : [ 6.   2.7  5.1  1.6]
# class: 2 virginica rate: 1.0

# %%
show_confusion_matrix('SVC', data, target, target_names,5, 0.3)
# Out:
# score:  0.977777777778
# [[15  0  0]
#  [ 0 15  1]
#  [ 0  0 14]]
# |实际\预测|setosa|versicolor|virginica|
# |-|-|-|-|
# |setosa|15|0|0|
# |versicolor|0|15|1|
# |virginica|0|0|14|
# class: 0 setosa rate: 1.0
# class: 1 versicolor rate: 0.9375
# predict to: virginica  : [ 5.9  3.2  4.8  1.8]
# class: 2 virginica rate: 1.0
